# %% [markdown]
# ## Check why NMF is unbalanced, possibly find another implementation
# ## VGG_BN => Re-run images
# ## Color t

# %%
# %load_ext autoreload
# %autoreload 2
from pipeline import get_maps, normalized, normalized_k, normalized_all, gen_maps, show_maps
from helpers import load_image, load_image2

import numpy as np

import matplotlib.pyplot as plt
#%autoreload 2
# %matplotlib inline

#Datastructure
from collections import OrderedDict

import skimage
import colormath
from colormath.color_conversions import convert_color
from colormath.color_objects import LabColor, LCHabColor, SpectralColor, sRGBColor

DATA_PATH = '../data/'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
source_path='/apple/1.jpg'
style_path='/apple/2.jpg'
K = 5

#Hs, Ws = gen_maps(source_path, style_path, K, up_width=400, layer_name="conv3_4", normalize_per_k=True)

# %%
def image_stats(image):
    l = image[:,:,0]
    a = image[:,:,1]
    b = image[:,:,2]
    (lMean, lStd) = (l.mean(), l.std())
    (aMean, aStd) = (a.mean(), a.std())
    (bMean, bStd) = (b.mean(), b.std())
    
    # return the color statistics
    return (lMean, lStd, aMean, aStd, bMean, bStd)

#https://www.pyimagesearch.com/2014/06/30/super-fast-color-transfer-images/
#source = color stats we want to match to target
def color_transfer(content, style):
    # compute color statistics for the source and target images
    (lMeanSrc, lStdSrc, aMeanSrc, aStdSrc, bMeanSrc, bStdSrc) = image_stats(content)
    (lMeanTar, lStdTar, aMeanTar, aStdTar, bMeanTar, bStdTar) = image_stats(style)
    
    # subtract the means from the target image
    l = content[:, :, 0]
    a = content[:, :, 1]
    b = content[:, :, 2]
    
    l -= lMeanSrc
    a -= aMeanSrc
    b -= bMeanSrc
    
    l = ( lStdSrc / lStdTar) * l
    a = ( aStdSrc / aStdTar) * a
    b = ( bStdSrc / bStdTar) * b
    
    '''

# scale by the standard deviations
    l = (lStdTar / lStdSrc) * l
    a = (aStdTar / aStdSrc) * a
    b = (bStdTar / bStdSrc) * b
    ''' 
    
    l += lMeanTar
    a += aMeanTar
    b += bMeanTar
    
    l = np.clip(l, 0, 100)
    
    #fix l
    #l = content[:, :, 0]
    
    print(b.min())
    
    transfer = np.array([l, a, b])
    transfer = np.swapaxes(transfer, axis1=0, axis2=2)
    transfer = np.swapaxes(transfer, axis1=0, axis2=1)
    
    #print(transfer.max())
    #print(transfer.min())
    
    transfer = skimage.color.lab2rgb(transfer)
    
    return transfer

#slow and not better than skimage
def rgb_to_lab(img):
    for i in range(0, img.shape[0]):
        for j in range(0, img.shape[1]):
                rgb = sRGBColor(img[i,j,0], img[i,j,1], img[i,j,2])
                lab = convert_color(rgb, LabColor)
                img[i,j,0] = lab.lab_l
                img[i,j,1] = lab.lab_a
                img[i,j,2] = lab.lab_b
            
    return img;

# %%
img_content = skimage.io.imread(DATA_PATH + source_path)
img_style = skimage.io.imread(DATA_PATH + style_path)
plt.imshow(img_content)

# %%
plt.imshow(img_style)

# %%
img_c_lab = skimage.color.rgb2lab(img_content)
img_s_lab = skimage.color.rgb2lab(img_style)

# %%
#t = color_transfer(img_c_lab, img_s_lab)
#plt.imshow(t)
t = color_transfer(img_c_lab, img_s_lab)
plt.imshow(t)
# Out:
# 8.89299318702

# %%
img_content = skimage.io.imread("../data/sunset2.jpg")
img_style = skimage.io.imread("../data/sunset.jpg")

img_c_lab = skimage.color.rgb2lab(img_content/255)
img_s_lab = skimage.color.rgb2lab(img_style/255)

t = color_transfer(img_c_lab, img_s_lab)
plt.imshow(t)
# Out:
# 7.59550212474
# C:\Users\Adan\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\skimage\color\colorconv.py:985: UserWarning: Color data out of range: Z < 0 in 1142 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)

# %%
K = 4
source_path='/apple/1.jpg'
style_path='/apple/2.jpg'
#Hs, Ws = gen_maps(source_path, style_path, K, up_width=224, layer_name="conv3_4", normalize_per_k=False)
show_maps(image1_path=source_path, image2_path=style_path, K=K, layer_name="conv4_4", cmap="Blues")

# %%
show_maps(image1_path=source_path, image2_path=style_path, K=K, layer_name="conv4_4", cmap="Blues", normalize_per_k=True)

# %%
show_maps(image1_path="../data/face/1.jpg", image2_path="../data/face/2.jpg", K=K, layer_name="conv3_3", cmap="Blues", normalize_per_k=True)
