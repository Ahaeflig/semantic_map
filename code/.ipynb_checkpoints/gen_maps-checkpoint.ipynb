# %%
#%load_ext autoreload
#%autoreload 2
from pipeline import get_maps

# %%
get_maps(image1_path='../data/city/1.jpg',image2_path='../data/city/2.jpg', K=10)
# Out:
# npy file loaded
# build model started
# build model finished: 0s
# ('Top1: ', 'n03388043 fountain i wrote something here', 0.66071224)
# ('Top5: ', [('n03388043 fountain i wrote something here', 0.66071224), ('n03877845 palace', 0.067487575), ('n02980441 castle', 0.045355964), ('n03933933 pier', 0.042192951), ('n09428293 seashore, coast, seacoast, sea-coast', 0.036209203)])
# ('Top1: ', 'n03388043 fountain i wrote something here', 0.66071224)
# ('Top5: ', [('n03388043 fountain i wrote something here', 0.66071224), ('n03877845 palace', 0.067487575), ('n02980441 castle', 0.045355964), ('n03933933 pier', 0.042192951), ('n09428293 seashore, coast, seacoast, sea-coast', 0.036209203)])
# [array([[[  4173.12654227,   3410.93239562,   1598.77478188, ...,
#              464.03101315,   4024.58772219,    400.34706088],
#          [  1581.71254935,   3506.02333052,   1024.517528  , ...,
#              626.31593818,   4213.10114557,     30.89147242],
# ...

# %%
[asd, kek] = get_maps(image1_path='../data/city/1.jpg',image2_path='../data/city/2.jpg', K=10)
# Out:
# npy file loaded
# build model started
# build model finished: 0s
# ('Top1: ', 'n03388043 fountain i wrote something here', 0.66071224)
# ('Top5: ', [('n03388043 fountain i wrote something here', 0.66071224), ('n03877845 palace', 0.067487575), ('n02980441 castle', 0.045355964), ('n03933933 pier', 0.042192951), ('n09428293 seashore, coast, seacoast, sea-coast', 0.036209203)])
# ('Top1: ', 'n03388043 fountain i wrote something here', 0.66071224)
# ('Top5: ', [('n03388043 fountain i wrote something here', 0.66071224), ('n03877845 palace', 0.067487575), ('n02980441 castle', 0.045355964), ('n03933933 pier', 0.042192951), ('n09428293 seashore, coast, seacoast, sea-coast', 0.036209203)])
