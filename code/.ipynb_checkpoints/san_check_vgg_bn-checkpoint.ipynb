# %%
# %load_ext autoreload
# %autoreload 2
from pipeline import show_maps
from helpers import load_image, load_image2

import numpy as np

import matplotlib.pyplot as plt
#%autoreload 2
# %matplotlib inline

#Datastructure
from collections import OrderedDict

import skimage

DATA_PATH = '../data/'

# %% [markdown]
# # VGG pred

# %%
image1_path='../data/tiger/1.jpg'
image2_path='../data/tiger/2.jpg'
K = 1
show_maps(image1_path, image2_path, K, up_width=224, layer_name="conv3_4", cmap="Blues", normalize_per_k=True)
# Out:
# ('Top1: ', 'n02129604 tiger, Panthera tigris', 0.69610667)
# ('Top5: ', [('n02129604 tiger, Panthera tigris', 0.69610667), ('n02123159 tiger cat', 0.30369553), ('n02391049 zebra', 0.00011224658), ('n02128925 jaguar, panther, Panthera onca, Felis onca', 3.5058394e-05), ('n02128385 leopard, Panthera pardus', 2.165588e-05)])
# ('Top1: ', 'n02129604 tiger, Panthera tigris', 0.73648685)
# ('Top5: ', [('n02129604 tiger, Panthera tigris', 0.73648685), ('n02123159 tiger cat', 0.26198962), ('n02128925 jaguar, panther, Panthera onca, Felis onca', 0.00098622451), ('n02128385 leopard, Panthera pardus', 0.00025433704), ('n02127052 lynx, catamount', 7.2258277e-05)])

# %%
image1_path='../data/tiger/3.jpg'
image2_path='../data/tiger/4.jpg'
K = 1
show_maps(image1_path, image2_path, K, up_width=224, layer_name="conv3_4", cmap="Blues", normalize_per_k=False)
# Out:
# ('Top1: ', 'n02747177 ashcan, trash can, garbage can, wastebin, ash bin, ash-bin, ashbin, dustbin, trash barrel, trash bin', 0.95630205)
# ('Top5: ', [('n02747177 ashcan, trash can, garbage can, wastebin, ash bin, ash-bin, ashbin, dustbin, trash barrel, trash bin', 0.95630205), ('n03903868 pedestal, plinth, footstall', 0.014562546), ('n03482405 hamper', 0.011872044), ('n03843555 oil filter', 0.0096955774), ('n02795169 barrel, cask', 0.0013434973)])
# ('Top1: ', 'n02909870 bucket, pail', 0.59961343)
# ('Top5: ', [('n02909870 bucket, pail', 0.59961343), ('n02747177 ashcan, trash can, garbage can, wastebin, ash bin, ash-bin, ashbin, dustbin, trash barrel, trash bin', 0.327723), ('n02795169 barrel, cask', 0.032724563), ('n03259280 Dutch oven', 0.0068321051), ('n03764736 milk can', 0.0060081831)])

# %% [markdown]
# # VGG_BN

# %%
np.set_printoptions(threshold=np.inf)
image1_path='../data/tiger/1.jpg'
image2_path='../data/tiger/2.jpg'
K = 1
show_maps(image1_path, image2_path, K, up_width=224, layer_name="conv3_4", cmap="Blues", normalize_per_k=True)
# Out:
# [[  0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   1.85536668e-02   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   2.90475815e-04   5.45540452e-01
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   4.38007832e-01   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   1.10801697e+00   0.00000000e+00
# ...
